# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de la page Amazon
url = "https://www.amazon.fr/s?k=livres&__mk_fr_FR=ÅMÅŽÕÑ&crid=18QYHZLRIFKL5&sprefix=livres%2Caps%2C75&ref=nb_sb_noss_1"

# En-têtes HTTP pour simuler un navigateur
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36",
    "Accept-Language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
}

# Envoyer la requête HTTP
response = requests.get(url, headers=headers)

# Vérifier si la requête a réussi
if response.status_code == 200:
    print("Page fetched successfully!")
else:
    print("Failed to fetch the page. Status code:", response.status_code)
    exit()

# Analyser le contenu HTML
soup = BeautifulSoup(response.content, 'lxml')

# Trouver tous les conteneurs de livres
books = soup.find_all('div', {'data-component-type': 's-search-result'})

# Extraire les titres et les prix
data = []
for book in books:
    title_element = book.find('span', class_='a-size-base-plus a-color-base a-text-normal')
    price_element = book.find('span', class_='a-offscreen')
    
    if title_element and price_element:
        title = title_element.get_text(strip=True)
        price = price_element.get_text(strip=True).replace('\xa0', ' ')
        data.append({'Title': title, 'Price': price})

# Créer un DataFrame à partir des données extraites
df = pd.DataFrame(data)

# Afficher le DataFrame
df
# Out:
# Page fetched successfully!
#                                                 Title    Price
# 0                          86, Amis d'enfance: Tome 1  15,68 €
# 1                           La sage-femme d'Auschwitz   8,60 €
# 2   Tu verras, les âmes se retrouvent toujours que...   8,30 €
# 3                                           La tresse   7,90 €
# 4                                         Jamais plus   7,60 €
# 5   Il n'y a pas de hasard, que des rendez-vous: R...  14,90 €
# 6   Le pouvoir du moment présent - Guide d'éveil s...   7,50 €
# 7   Personne ne doit savoir (Prix des lectrices 2023)   8,95 €
# 8   Les cinq blessures qui empêchent d'être soi-mê...   8,60 €
# 9                                Tout le bleu du ciel  10,90 €
# 10                                       Lait et miel   8,60 €
# 11  Valerie Perrin Changer L'eau Des Fleurs Poche ...   9,90 €
# 12  Par-delà le Monde, Je t'aimerai: Un voyage ver...  11,98 €
# 13                                   Les Yeux de Mona  22,90 €
# 14  Quelqu'un d'autre - Nouveau roman 2024 (Littér...  14,99 €
# 15                                 La femme de ménage   8,60 €
# 16              Kilomètre zéro : Le chemin du bonheur   7,90 €
# 17                             Plus grand que le ciel  20,90 €
# 18   Influence et manipulation - 3e édition augmentée   8,60 €
# 19      Un monde presque parfait - Nouveau roman 2024  22,90 €
# 20             La chronique des Bridgerton: Tomes 1&2  15,90 €
# 21  Les quatre accords toltèques: La voie de la li...   8,95 €
# 22                        Les Femmes du bout du monde   9,40 €
# 23                              Histoire de Jérusalem  27,00 €
# 24  Entretien avec un cadavre: Un médecin légiste ...  19,90 €
# 25  Cahier Écriture Française Grands, 4 Livres sur...  11,99 €
# 26  MEURTRES-FRITES à la crème: un roman policier ...  13,90 €
# 27                            Hannya: Livre 1 : Alice  14,99 €
# 28                                 Le Joueur d'échecs   3,00 €
# 29                                         L'étranger   6,30 €
# 30    Hadès et Perséphone - Tome 04: A touch of Chaos  18,00 €
# 31  La Traversée des temps - tome 4 - La Lumière d...  23,90 €
# 32  Les morts ont la parole: Philippe Boxho, médec...  19,90 €
# 33                                           Antigone   6,50 €
# 34              Veiller sur elle - Prix Goncourt 2023   0,00 €
# 35  Au-delà du ciel - Comprendre l'univers grâce a...  24,90 €
# 36  Norferville - Nouveauté Franck Thilliez 2024 -...  22,90 €
# 37  Le singe et la fleur de lotus: 52 histoires bo...  14,95 €
# 38                       Les derniers jours de Johnny  20,00 €
# 39                                  Le Barman du Ritz  21,90 €
# 40                                Je vais aller mieux  13,99 €
# 41  Cahiers de Douai (oeuvre au programme Bac de f...   2,50 €
# 42                                   Astuces de génie  15,90 €
# 43  Coloriages mystères Disney - Les Grands classi...  14,95 €
# 44                                   Captive - tome 2  20,90 €
# 45       Comment se faire des amis (Nouvelle édition)   8,90 €
# 46                          Le Problème à trois corps  11,00 €
# 47  Zéro sucre & IG bas, le déclic santé: Toutes l...  19,95 €
# 48     Un printemps pour te succomber: Seasons Tome 3  17,00 €
# 49  Fsolis DIY Book Nook Kit Maison de Poupées Min...  51,99 €
