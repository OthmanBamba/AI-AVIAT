# %%
#!pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2024.8.30)

# %%
#pip install psycopg2

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# Clé API d'AviationStack
api_key = "fcd29088b7d6cbf8974ee006213f27b6"  

# URL de l'API AviationStack pour les informations sur les vols
url = "http://api.aviationstack.com/v1/flights"
# Paramètres pour la requête API
params = {
    'access_key': api_key,
    'limit': 100,   # Nombre de résultats à afficher
    'arr_iata': 'CDG',  # Aéroport d'arrivée (ici Paris Charles de Gaulle)
   
}

# Envoi de la requête GET
response = requests.get(url, params=params)

# Vérification de la réponse
if response.status_code == 200:
    data = response.json()  # Conversion de la réponse en format JSON
    flights_data = data['data']  # Extraire les données des vols
else:
    print(f"Erreur lors de la requête : {response.status_code}")
    flights_data = []

# %%
# DataFrame Pandas pour gérer les données
flights_df = pd.DataFrame(flights_data)

# Vérification  si le DataFrame est vide
if flights_df.empty:
    print("Aucune donnée de vol disponible.")
else:
    # Aplatir le DataFrame
    flights_df = pd.DataFrame({
        'flight_date': flights_df['departure'].apply(lambda x: x.get('estimated') if isinstance(x, dict) else None),
        'flight_status': flights_df['flight_status'],
        'airline': flights_df['airline'].apply(lambda x: x.get('name') if isinstance(x, dict) else None),
        'flight': flights_df['flight'].apply(lambda x: x.get('iata') if isinstance(x, dict) else None),
        'aircraft': flights_df['aircraft'].apply(lambda x: x.get('iata') if isinstance(x, dict) else None),
        'live': flights_df['live'],
        'departure_airport': flights_df['departure'].apply(lambda x: x.get('airport') if isinstance(x, dict) else None),
        'departure_time': flights_df['departure'].apply(lambda x: x.get('estimated') if isinstance(x, dict) else None),
        'arrival_airport': flights_df['arrival'].apply(lambda x: x.get('airport') if isinstance(x, dict) else None),
        'arrival_time': flights_df['arrival'].apply(lambda x: x.get('estimated') if isinstance(x, dict) else None),
    })

    # Conversion  explicit toutes les colonnes en type chaîne pour éviter les problèmes de type dict
    for column in flights_df.columns:
        flights_df[column] = flights_df[column].astype(str)
        
# Affichage des types de données et des premières lignes

flights_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # DataFrame Pandas pour gérer les données
# ----> 2 flights_df = pd.DataFrame(flights_data)
#       4 # Vérification  si le DataFrame est vide
#       5 if flights_df.empty:
#
# NameError: name 'flights_data' is not defined

# %%
# Connexion à la base de données PostgreSQL
engine = create_engine('postgresql://benothmane:Deguzzy1991%40@localhost:5432/aviation_db')

    # Tentative de sauvegarde du DataFrame dans la table PostgreSQL
try:
        flights_df.to_sql('flights', engine, if_exists='replace', index=False)
        print("Les données ont été sauvegardées dans PostgreSQL.")
except Exception as e:
        print(f"Erreur lors de l'enregistrement dans PostgreSQL : {e}")
# Out:
# Les données ont été sauvegardées dans PostgreSQL.

# %%
#  DataFrame pour voir les données
print("Données de vol récupérées :")
flights_df.head() # Affiche les premières lignes du DataFrame
# Out:
# Données de vol récupérées :
#                  flight_date flight_status            airline  flight  \
# 0  2024-11-09T00:05:00+00:00     scheduled    Xiamen Airlines   MF825
# 1  2024-11-08T08:15:00+00:00        landed  Brussels Airlines  SN3633
# 2  2024-11-08T13:05:00+00:00        active          Air India   AI143
# 3  2024-11-08T08:25:00+00:00        landed         Air Canada  AC2971
# 4  2024-11-08T08:25:00+00:00        landed         Air France  AF5075
#
#   aircraft                                               live  \
# 0     None                                               None
# 1     A320                                               None
# 2     B788  {'updated': '2024-11-08T09:57:18+00:00', 'lati...
# 3     None                                               None
# 4     None                                               None
#
#              departure_airport             departure_time    arrival_airport  \
# 0                       Xiamen  2024-11-09T00:05:00+00:00  Charles De Gaulle
# 1             Brussels Airport  2024-11-08T08:15:00+00:00  Charles De Gaulle
# 2  Indira Gandhi International  2024-11-08T13:05:00+00:00  Charles De Gaulle
# 3                        Pleso  2024-11-08T08:25:00+00:00  Charles De Gaulle
# 4                        Pleso  2024-11-08T08:25:00+00:00  Charles De Gaulle
#
#                 arrival_time
# 0  2024-11-09T06:00:00+00:00
# 1  2024-11-08T09:15:00+00:00
# 2  2024-11-08T17:55:00+00:00
# 3  2024-11-08T10:30:00+00:00
# 4  2024-11-08T10:30:00+00:00

# %%
 # Exportation  des données vers un fichier CSV
output_file_path = "/Users/benothmane/Desktop/flight_dashboard/upload/folder/NEW_vols1.csv"
flights_df.to_csv(output_file_path, index=False)
print(f"Les données ont été exportées vers {output_file_path}.")
# Out:
# Les données ont été exportées vers /Users/benothmane/Desktop/flight_dashboard/upload/folder/NEW_vols1.csv.

# %% [markdown]
# L’objectif est de prédire les besoins en stationnement d’un avion à l’aéroport en fonction des données collectées comme la date, l’heure d'arrivée, le statut du vol, etc.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import joblib 

#Importation du dataset 
# Lecture  CSV
df = pd.read_csv('/Users/benothmane/Desktop/flight_dashboard/upload/folder/NEW_vols.csv')

# Afficher le DataFrame
df
# Out:
#                   flight_date flight_status            airline  flight  \
# 0   2024-11-09T00:05:00+00:00     scheduled    Xiamen Airlines   MF825
# 1   2024-11-08T08:15:00+00:00        landed  Brussels Airlines  SN3633
# 2   2024-11-08T13:05:00+00:00        active          Air India   AI143
# 3   2024-11-08T08:25:00+00:00        landed         Air Canada  AC2971
# 4   2024-11-08T08:25:00+00:00        landed         Air France  AF5075
# ..                        ...           ...                ...     ...
# 95  2024-11-08T09:30:00+00:00        active            easyJet  U24648
# 96  2024-11-08T09:10:00+00:00        active          Norwegian  DY3638
# 97  2024-11-08T10:00:00+00:00        active         Air France  AF1067
# 98  2024-11-08T10:00:00+00:00        active            WestJet  WS5173
# 99  2024-11-08T10:00:00+00:00        active                KLM  KL2127
#
#    aircraft                                               live  \
# 0       NaN                                                NaN
# 1      A320                                                NaN
# 2      B788  {'updated': '2024-11-08T09:57:18+00:00', 'lati...
# 3       NaN                                                NaN
# 4       NaN                                                NaN
# ..      ...                                                ...
# 95     A320  {'updated': '2024-11-08T09:59:55+00:00', 'lati...
# 96      NaN                                                NaN
# 97     A318  {'updated': '2024-11-08T09:59:56+00:00', 'lati...
# 98      NaN                                                NaN
# 99      NaN                                                NaN
#
#               departure_airport             departure_time    arrival_airport  \
# 0                        Xiamen  2024-11-09T00:05:00+00:00  Charles De Gaulle
# 1              Brussels Airport  2024-11-08T08:15:00+00:00  Charles De Gaulle
# 2   Indira Gandhi International  2024-11-08T13:05:00+00:00  Charles De Gaulle
# 3                         Pleso  2024-11-08T08:25:00+00:00  Charles De Gaulle
# 4                         Pleso  2024-11-08T08:25:00+00:00  Charles De Gaulle
# ..                          ...                        ...                ...
# 95                      Kastrup  2024-11-08T09:30:00+00:00  Charles De Gaulle
# 96                      Kastrup  2024-11-08T09:10:00+00:00  Charles De Gaulle
# 97                     Peretola  2024-11-08T10:00:00+00:00  Charles De Gaulle
# 98                     Peretola  2024-11-08T10:00:00+00:00  Charles De Gaulle
# 99                     Peretola  2024-11-08T10:00:00+00:00  Charles De Gaulle
#
#                  arrival_time
# 0   2024-11-09T06:00:00+00:00
# 1   2024-11-08T09:15:00+00:00
# 2   2024-11-08T17:55:00+00:00
# 3   2024-11-08T10:30:00+00:00
# 4   2024-11-08T10:30:00+00:00
# ..                        ...
# 95  2024-11-08T11:35:00+00:00
# 96  2024-11-08T11:10:00+00:00
# 97  2024-11-08T11:50:00+00:00
# 98  2024-11-08T11:50:00+00:00
# 99  2024-11-08T11:50:00+00:00
#
# [100 rows x 10 columns]

# %%
# Nettoyage des données en supprimant les lignes avec des valeurs manquantes
df_cleaned = df.dropna(subset=['flight_status', 'airline', 'departure_airport', 'arrival_airport', 'departure_time', 'arrival_time'])

# Conversion des dates
df_cleaned['departure_time'] = pd.to_datetime(df_cleaned['departure_time'])
df_cleaned['arrival_time'] = pd.to_datetime(df_cleaned['arrival_time'])

# Création de la variable cible "needs_parking" (1 si "landed", 0 sinon)
df_cleaned['needs_parking'] = np.where(df_cleaned['flight_status'] == 'landed', 1, 0)

# Extraction des heures de départ et d'arrivée
df_cleaned['departure_hour'] = df_cleaned['departure_time'].dt.hour
df_cleaned['arrival_hour'] = df_cleaned['arrival_time'].dt.hour

# Sélection des caractéristiques pour l'entraînement
X = df_cleaned[['flight', 'flight_status', 'airline', 'departure_hour', 'arrival_hour', 'departure_airport', 'arrival_airport']]
y = df_cleaned['needs_parking']

# Encodage des variables catégorielles
label_encoders = {}
for column in ['flight_status', 'airline', 'departure_airport', 'arrival_airport']:
    le = LabelEncoder()
    X.loc[:, column] = le.fit_transform(X[column])  # Utiliser .loc pour éviter l'avertissement SettingWithCopyWarning
    label_encoders[column] = le

# Encodage de la colonne "flight" en codes de catégories
X.loc[:, 'flight'] = X['flight'].astype('category').cat.codes

# Séparation des données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# Entraînement du modèle RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
model.fit(X_train, y_train)

# Chemin pour sauvegarder le modèle
MODEL_PATH = '/Users/benothmane/Desktop/flight_dashboard/models/new_model_new3.pkl'
# Sauvegarde du  modèle
joblib.dump(model, MODEL_PATH)
print(f"Modèle sauvegardé avec succès à l'emplacement : {MODEL_PATH}")

# Prédictions sur l'ensemble de test
y_pred = model.predict(X_test)

# Rapport de classification pour évaluer les performances
classification_rep = classification_report(y_test, y_pred)
print("Rapport de classification :\n", classification_rep)

# Vérification des valeurs uniques prédites
predicted_unique_values = np.unique(y_pred)
print("Valeurs uniques prédites : ", predicted_unique_values)

# Affichage des résultats des prédictions sur l'ensemble de test
results = X_test.copy()
results['needs_parking'] = y_pred

# Décodage des variables catégorielles pour les résultats
results['airline'] = label_encoders['airline'].inverse_transform(results['airline'].astype(int))
results['flight_status'] = label_encoders['flight_status'].inverse_transform(results['flight_status'].astype(int))
results['departure_airport'] = label_encoders['departure_airport'].inverse_transform(results['departure_airport'].astype(int))
results['arrival_airport'] = label_encoders['arrival_airport'].inverse_transform(results['arrival_airport'].astype(int))

# Résultats des prédictions 
for index, row in results.iterrows():
    if row['needs_parking'] == 1:
        print(f"L'Avion de {row['airline']} (ID: {row['flight']}) nécessite un stationnement.")
    else:
        print(f"L'Avion de {row['airline']} (ID: {row['flight']}) ne nécessite pas de stationnement.")
# Out:
# Modèle sauvegardé avec succès à l'emplacement : /Users/benothmane/Desktop/flight_dashboard/models/new_model_new3.pkl
# Rapport de classification :
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        28
#            1       0.96      1.00      0.98        22
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
#
# Valeurs uniques prédites :  [0 1]
# L'Avion de Etihad Airways (ID: 45) ne nécessite pas de stationnement.
# L'Avion de Aeromexico (ID: 21) ne nécessite pas de stationnement.
# L'Avion de Vietnam Airlines (ID: 92) nécessite un stationnement.
# L'Avion de SAS (ID: 75) ne nécessite pas de stationnement.
# L'Avion de TAROM (ID: 70) ne nécessite pas de stationnement.
# L'Avion de Aerolineas Argentinas (ID: 26) ne nécessite pas de stationnement.
# L'Avion de easyJet (ID: 81) nécessite un stationnement.
# L'Avion de Air France (ID: 6) ne nécessite pas de stationnement.
# L'Avion de Georgian Airways (ID: 1) ne nécessite pas de stationnement.
# L'Avion de Xiamen Airlines (ID: 59) nécessite un stationnement.
# L'Avion de Icelandair (ID: 46) ne nécessite pas de stationnement.
# L'Avion de Vietnam Airlines (ID: 90) nécessite un stationnement.
# L'Avion de Air France (ID: 18) nécessite un stationnement.
# L'Avion de Air France (ID: 14) ne nécessite pas de stationnement.
# L'Avion de Lufthansa (ID: 58) ne nécessite pas de stationnement.
# L'Avion de Air France (ID: 15) nécessite un stationnement.
# L'Avion de easyJet (ID: 84) ne nécessite pas de stationnement.
# L'Avion de Delta Air Lines (ID: 40) ne nécessite pas de stationnement.
# L'Avion de Wings West Airlines (ID: 69) ne nécessite pas de stationnement.
# L'Avion de ITA Airways (ID: 29) nécessite un stationnement.
# L'Avion de Korean Air (ID: 53) ne nécessite pas de stationnement.
# L'Avion de Air France (ID: 16) ne nécessite pas de stationnement.
# L'Avion de Etihad Airways (ID: 43) nécessite un stationnement.
# L'Avion de Korean Air (ID: 52) ne nécessite pas de stationnement.
# L'Avion de Singapore Airlines (ID: 78) nécessite un stationnement.
# L'Avion de SAS (ID: 72) nécessite un stationnement.
# L'Avion de Finnair (ID: 27) ne nécessite pas de stationnement.
# L'Avion de Norwegian (ID: 42) ne nécessite pas de stationnement.
# L'Avion de Vistara (ID: 87) ne nécessite pas de stationnement.
# L'Avion de Jet Linx Aviation (ID: 51) nécessite un stationnement.
# L'Avion de Air France (ID: 11) ne nécessite pas de stationnement.
# L'Avion de WestJet (ID: 98) ne nécessite pas de stationnement.
# L'Avion de China Eastern Airlines (ID: 65) ne nécessite pas de stationnement.
# L'Avion de Kenya Airways (ID: 56) nécessite un stationnement.
# L'Avion de British Airways (ID: 31) nécessite un stationnement.
# L'Avion de Air India (ID: 20) nécessite un stationnement.
# L'Avion de China Eastern Airlines (ID: 66) nécessite un stationnement.
# L'Avion de Air Mauritius (ID: 63) nécessite un stationnement.
# L'Avion de KLM (ID: 55) ne nécessite pas de stationnement.
# L'Avion de Norwegian (ID: 41) ne nécessite pas de stationnement.
# L'Avion de Delta Air Lines (ID: 35) ne nécessite pas de stationnement.
# L'Avion de Air France (ID: 3) nécessite un stationnement.
# L'Avion de United Airlines (ID: 85) nécessite un stationnement.
# L'Avion de easyJet (ID: 83) ne nécessite pas de stationnement.
# L'Avion de Hainan Airlines (ID: 49) nécessite un stationnement.
# L'Avion de Cygnus Air (ID: -1) nécessite un stationnement.
# L'Avion de Aeromexico (ID: 23) ne nécessite pas de stationnement.
# L'Avion de Delta Air Lines (ID: 34) nécessite un stationnement.
# L'Avion de Alitalia (ID: 28) nécessite un stationnement.
# L'Avion de Aegean Airlines (ID: 0) nécessite un stationnement.

# %%
# Préparation des  données pour le DataFrame des résultats
predictions_data = []

# Listing des resultats
for index, row in results.iterrows():
    predictions_data.append({
        "Airline": row['airline'],
        "Flight ID": row['flight'],
        "Needs Parking": " nécessite un stationnement" if row['needs_parking'] == 1 else "ne nécessite pas de stationnement."
    })

# DataFrame des résultats
predictions_df = pd.DataFrame(predictions_data)

predictions_df # Afficher les premières lignes pour vérification
# Out:
#                    Airline  Flight ID                       Needs Parking
# 0           Etihad Airways         45  ne nécessite pas de stationnement.
# 1               Aeromexico         21  ne nécessite pas de stationnement.
# 2         Vietnam Airlines         92          nécessite un stationnement
# 3                      SAS         75  ne nécessite pas de stationnement.
# 4                    TAROM         70  ne nécessite pas de stationnement.
# 5    Aerolineas Argentinas         26  ne nécessite pas de stationnement.
# 6                  easyJet         81          nécessite un stationnement
# 7               Air France          6  ne nécessite pas de stationnement.
# 8         Georgian Airways          1  ne nécessite pas de stationnement.
# 9          Xiamen Airlines         59          nécessite un stationnement
# 10              Icelandair         46  ne nécessite pas de stationnement.
# 11        Vietnam Airlines         90          nécessite un stationnement
# 12              Air France         18          nécessite un stationnement
# 13              Air France         14  ne nécessite pas de stationnement.
# 14               Lufthansa         58  ne nécessite pas de stationnement.
# 15              Air France         15          nécessite un stationnement
# 16                 easyJet         84  ne nécessite pas de stationnement.
# 17         Delta Air Lines         40  ne nécessite pas de stationnement.
# 18     Wings West Airlines         69  ne nécessite pas de stationnement.
# 19             ITA Airways         29          nécessite un stationnement
# 20              Korean Air         53  ne nécessite pas de stationnement.
# 21              Air France         16  ne nécessite pas de stationnement.
# 22          Etihad Airways         43          nécessite un stationnement
# 23              Korean Air         52  ne nécessite pas de stationnement.
# 24      Singapore Airlines         78          nécessite un stationnement
# 25                     SAS         72          nécessite un stationnement
# 26                 Finnair         27  ne nécessite pas de stationnement.
# 27               Norwegian         42  ne nécessite pas de stationnement.
# 28                 Vistara         87  ne nécessite pas de stationnement.
# 29       Jet Linx Aviation         51          nécessite un stationnement
# 30              Air France         11  ne nécessite pas de stationnement.
# 31                 WestJet         98  ne nécessite pas de stationnement.
# 32  China Eastern Airlines         65  ne nécessite pas de stationnement.
# 33           Kenya Airways         56          nécessite un stationnement
# 34         British Airways         31          nécessite un stationnement
# 35               Air India         20          nécessite un stationnement
# 36  China Eastern Airlines         66          nécessite un stationnement
# 37           Air Mauritius         63          nécessite un stationnement
# 38                     KLM         55  ne nécessite pas de stationnement.
# 39               Norwegian         41  ne nécessite pas de stationnement.
# 40         Delta Air Lines         35  ne nécessite pas de stationnement.
# 41              Air France          3          nécessite un stationnement
# 42         United Airlines         85          nécessite un stationnement
# 43                 easyJet         83  ne nécessite pas de stationnement.
# 44         Hainan Airlines         49          nécessite un stationnement
# 45              Cygnus Air         -1          nécessite un stationnement
# 46              Aeromexico         23  ne nécessite pas de stationnement.
# 47         Delta Air Lines         34          nécessite un stationnement
# 48                Alitalia         28          nécessite un stationnement
# 49         Aegean Airlines          0          nécessite un stationnement

# %%
# Comptage du nombre d'avions nécessitant un stationnement ou non
parking_counts = results['needs_parking'].value_counts()

# Histogramme pour visualiser les résultats
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(['Ne nécessite pas de stationnement', 'Nécessite un stationnement'], parking_counts, color=['blue', 'green'])
plt.title("Nombre d'avions nécessitant un stationnement ou non")
plt.xlabel("Stationnement")
plt.ylabel("Nombre d'avions")
plt.show()

# %%
# Comptage du nombre d'avions nécessitant un stationnement ou non
parking_counts = results['needs_parking'].value_counts()

# Diagramme en camembert pour visualiser les résultats
plt.figure(figsize=(8, 8))
plt.pie(parking_counts, labels=['Ne nécessite pas de stationnement', 'Nécessite un stationnement'], 
        autopct='%1.1f%%', colors=['blue', 'green'], startangle=140)
plt.title("Répartition des avions nécessitant un stationnement ou non")
plt.show()

# %%
# Stockage des résultats
predictions_data = []

# Parcours des résultats pour les ajouter à la liste
for index, row in results.iterrows():
    predictions_data.append({
        "Airline": row['airline'],
        "Flight ID": row['flight'],
        "Needs Parking": "nécessite un stationnement" if row['needs_parking'] == 1 else "ne nécessite pas de stationnement."
    })

# DataFrame des résultats
predictions_df = pd.DataFrame(predictions_data)

# Sauvegarder le DataFrame de prédiction dans un fichier CSV
output_file_path = '/Users/benothmane/Desktop/flight_dashboard/upload/folder/VOL_pred2.csv'
predictions_df.to_csv(output_file_path, index=False, sep='\t')  # Utiliser un séparateur tabulaire

print(f"DataFrame sauvegardé dans {output_file_path}")
# Out:
# DataFrame sauvegardé dans /Users/benothmane/Desktop/flight_dashboard/upload/folder/VOL_pred2.csv

# %% [markdown]
# DEFINITION DU MODELE D'OPTIMISATION

# %%
import pandas as pd
from sklearn.metrics import classification_report

# Affichage des résultats des prédictions sur l'ensemble de test
results = X_test.copy()
results['needs_parking'] = y_pred

# Décodage des variables catégorielles pour les résultats
results['airline'] = label_encoders['airline'].inverse_transform(results['airline'].astype(int))
results['flight_status'] = label_encoders['flight_status'].inverse_transform(results['flight_status'].astype(int))
results['departure_airport'] = label_encoders['departure_airport'].inverse_transform(results['departure_airport'].astype(int))
results['arrival_airport'] = label_encoders['arrival_airport'].inverse_transform(results['arrival_airport'].astype(int))

# Vérification de la correspondance des longueurs
if len(results) != len(y_pred):
    print("Erreur: La longueur de results et y_pred ne correspond pas.")
else:
    # Rapport de classification pour évaluer les performances
    classification_rep = classification_report(y_test, y_pred)
    print("Rapport de classification :\n", classification_rep)

    # Vérification des valeurs uniques prédites
    predicted_unique_values = np.unique(y_pred)
    print("Valeurs uniques prédites : ", predicted_unique_values)

    # Optimisation des résultats
    optimized_results = []
    for index, row in results.iterrows():
        # Créer un dictionnaire pour chaque vol
        result_entry = {
            "Airline": row['airline'],
            "Flight ID": row['flight'],
            "Needs Parking": None
        }

        print(f"Analyse du vol : {row['flight']} de la compagnie {row['airline']}")

        if row['needs_parking'] == 1:
            print(f"L'Avion de {row['airline']} (ID: {row['flight']}) peut stationner sur le tarmac ,espace libre" )
            result_entry["Needs Parking"] = "peut stationner"
        else:
            print(f"L'Avion de {row['airline']} (ID: {row['flight']})  ne peut pas stationner sur le tarmac !!!!")
            # Logique d'optimisation supplémentaire pour les heures de pointe
            if row['arrival_hour'] in [7, 8, 17, 18]:  # Heures de pointe
                print("Attention : l'atterrissage aura  eu lieu pendant les heures de pointe, le stationnement pourrait être compliqué!!!!!!")
                result_entry["Needs Parking"] = "Atterrissage pendant les heures de pointe, réaménagement immédiat!!!!!!!!!"
            else:
                result_entry["Needs Parking"] = "Ne peut pas stationner!!!!!!"

        optimized_results.append(result_entry)

    # Création d'un DataFrame à partir des résultats optimisés
    df_optimized_results = pd.DataFrame(optimized_results)
    df_optimized_results
# Out:
# Rapport de classification :
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        28
#            1       0.96      1.00      0.98        22
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
#
# Valeurs uniques prédites :  [0 1]
# Analyse du vol : 45 de la compagnie Etihad Airways
# L'Avion de Etihad Airways (ID: 45)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 21 de la compagnie Aeromexico
# L'Avion de Aeromexico (ID: 21)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 92 de la compagnie Vietnam Airlines
# L'Avion de Vietnam Airlines (ID: 92) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 75 de la compagnie SAS
# L'Avion de SAS (ID: 75)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 70 de la compagnie TAROM
# L'Avion de TAROM (ID: 70)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 26 de la compagnie Aerolineas Argentinas
# L'Avion de Aerolineas Argentinas (ID: 26)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 81 de la compagnie easyJet
# L'Avion de easyJet (ID: 81) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 6 de la compagnie Air France
# L'Avion de Air France (ID: 6)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 1 de la compagnie Georgian Airways
# L'Avion de Georgian Airways (ID: 1)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 59 de la compagnie Xiamen Airlines
# L'Avion de Xiamen Airlines (ID: 59) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 46 de la compagnie Icelandair
# L'Avion de Icelandair (ID: 46)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 90 de la compagnie Vietnam Airlines
# L'Avion de Vietnam Airlines (ID: 90) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 18 de la compagnie Air France
# L'Avion de Air France (ID: 18) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 14 de la compagnie Air France
# L'Avion de Air France (ID: 14)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 58 de la compagnie Lufthansa
# L'Avion de Lufthansa (ID: 58)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 15 de la compagnie Air France
# L'Avion de Air France (ID: 15) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 84 de la compagnie easyJet
# L'Avion de easyJet (ID: 84)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 40 de la compagnie Delta Air Lines
# L'Avion de Delta Air Lines (ID: 40)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 69 de la compagnie Wings West Airlines
# L'Avion de Wings West Airlines (ID: 69)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 29 de la compagnie ITA Airways
# L'Avion de ITA Airways (ID: 29) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 53 de la compagnie Korean Air
# L'Avion de Korean Air (ID: 53)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 16 de la compagnie Air France
# L'Avion de Air France (ID: 16)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 43 de la compagnie Etihad Airways
# L'Avion de Etihad Airways (ID: 43) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 52 de la compagnie Korean Air
# L'Avion de Korean Air (ID: 52)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 78 de la compagnie Singapore Airlines
# L'Avion de Singapore Airlines (ID: 78) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 72 de la compagnie SAS
# L'Avion de SAS (ID: 72) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 27 de la compagnie Finnair
# L'Avion de Finnair (ID: 27)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 42 de la compagnie Norwegian
# L'Avion de Norwegian (ID: 42)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 87 de la compagnie Vistara
# L'Avion de Vistara (ID: 87)  ne peut pas stationner sur le tarmac !!!!
# Attention : l'atterrissage aura  eu lieu pendant les heures de pointe, le stationnement pourrait être compliqué!!!!!!
# Analyse du vol : 51 de la compagnie Jet Linx Aviation
# L'Avion de Jet Linx Aviation (ID: 51) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 11 de la compagnie Air France
# L'Avion de Air France (ID: 11)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 98 de la compagnie WestJet
# L'Avion de WestJet (ID: 98)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 65 de la compagnie China Eastern Airlines
# L'Avion de China Eastern Airlines (ID: 65)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 56 de la compagnie Kenya Airways
# L'Avion de Kenya Airways (ID: 56) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 31 de la compagnie British Airways
# L'Avion de British Airways (ID: 31) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 20 de la compagnie Air India
# L'Avion de Air India (ID: 20) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 66 de la compagnie China Eastern Airlines
# L'Avion de China Eastern Airlines (ID: 66) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 63 de la compagnie Air Mauritius
# L'Avion de Air Mauritius (ID: 63) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 55 de la compagnie KLM
# L'Avion de KLM (ID: 55)  ne peut pas stationner sur le tarmac !!!!
# Attention : l'atterrissage aura  eu lieu pendant les heures de pointe, le stationnement pourrait être compliqué!!!!!!
# Analyse du vol : 41 de la compagnie Norwegian
# L'Avion de Norwegian (ID: 41)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 35 de la compagnie Delta Air Lines
# L'Avion de Delta Air Lines (ID: 35)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 3 de la compagnie Air France
# L'Avion de Air France (ID: 3) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 85 de la compagnie United Airlines
# L'Avion de United Airlines (ID: 85) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 83 de la compagnie easyJet
# L'Avion de easyJet (ID: 83)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 49 de la compagnie Hainan Airlines
# L'Avion de Hainan Airlines (ID: 49) peut stationner sur le tarmac ,espace libre
# Analyse du vol : -1 de la compagnie Cygnus Air
# L'Avion de Cygnus Air (ID: -1) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 23 de la compagnie Aeromexico
# L'Avion de Aeromexico (ID: 23)  ne peut pas stationner sur le tarmac !!!!
# Analyse du vol : 34 de la compagnie Delta Air Lines
# L'Avion de Delta Air Lines (ID: 34) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 28 de la compagnie Alitalia
# L'Avion de Alitalia (ID: 28) peut stationner sur le tarmac ,espace libre
# Analyse du vol : 0 de la compagnie Aegean Airlines
# L'Avion de Aegean Airlines (ID: 0) peut stationner sur le tarmac ,espace libre

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df_optimized_results = pd.DataFrame(data)

# Compter le nombre de vols selon les besoins de stationnement
parking_counts = df_optimized_results['Needs Parking'].value_counts()

# Histogramme (Bar Chart)
plt.figure(figsize=(10, 6))
sns.barplot(x=parking_counts.index, y=parking_counts.values, hue=parking_counts.index, palette="viridis", dodge=False)
plt.title('Nombre de Vols selon les Besoins de Stationnement')
plt.xlabel('Besoins de Stationnement')
plt.ylabel('Nombre de Vols')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Camembert (Pie Chart)
plt.figure(figsize=(8, 8))
plt.pie(parking_counts, labels=parking_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title('Répartition des Besoins de Stationnement')
plt.axis('equal')  # Pour que le camembert soit un cercle
plt.show()

# %% [markdown]
# TEST ET VALIDATION DU MODELE

# %%
# Cellule 1: Demander à l'utilisateur de saisir le chemin du fichier CSV
csv_file_path = input("Veuillez entrer le chemin du fichier CSV : ")

# Cellule 2: Charger les données du fichier CSV
df = pd.read_csv(csv_file_path)

# Cellule 3: Demander à l'utilisateur de saisir le chemin du modèle préalablement sauvegardé
model_path = input("Veuillez entrer le chemin du modèle (fichier .pkl) : ")
model = joblib.load(model_path)  # Charger le modèle

# Cellule 4: Préparation des données pour la prédiction
df_cleaned = df.dropna(subset=['flight_status', 'airline', 'departure_airport', 'arrival_airport', 'departure_time', 'arrival_time'])
df_cleaned['departure_time'] = pd.to_datetime(df_cleaned['departure_time'])
df_cleaned['arrival_time'] = pd.to_datetime(df_cleaned['arrival_time'])
df_cleaned['departure_hour'] = df_cleaned['departure_time'].dt.hour
df_cleaned['arrival_hour'] = df_cleaned['arrival_time'].dt.hour

# Sélection et encodage des caractéristiques
X = df_cleaned[['flight', 'flight_status', 'airline', 'departure_hour', 'arrival_hour', 'departure_airport', 'arrival_airport']].copy()  # Utilisation de .copy()
for column in ['flight_status', 'airline', 'departure_airport', 'arrival_airport']:
    le = LabelEncoder()
    X[column] = le.fit_transform(X[column])

X['flight'] = X['flight'].astype('category').cat.codes  # Pas de SettingWithCopyWarning

# Cellule 5: Prédictions sur les données
y_pred = model.predict(X)

# Ajouter les résultats de prédiction au DataFrame
df_cleaned['needs_parking'] = y_pred

# Cellule 6: Créer un DataFrame pour les résultats
results_df = df_cleaned[['flight', 'airline', 'flight_status', 'needs_parking']].copy()
results_df['needs_parking'] = results_df['needs_parking'].map({1: 'Nécessite un stationnement', 0: 'Ne nécessite pas de stationnement'})

# Affichage du DataFrame des résultats
results_df
# Out:
# Veuillez entrer le chemin du fichier CSV :  /Users/benothmane/Desktop/flight_dashboard/upload/folder/NEW_vols.csv
# Veuillez entrer le chemin du modèle (fichier .pkl) :  /Users/benothmane/Desktop/flight_dashboard/models/new_model.pkl
#     flight            airline flight_status                      needs_parking
# 0    MF825    Xiamen Airlines     scheduled  Ne nécessite pas de stationnement
# 1   SN3633  Brussels Airlines        landed         Nécessite un stationnement
# 2    AI143          Air India        active  Ne nécessite pas de stationnement
# 3   AC2971         Air Canada        landed         Nécessite un stationnement
# 4   AF5075         Air France        landed         Nécessite un stationnement
# ..     ...                ...           ...                                ...
# 95  U24648            easyJet        active         Nécessite un stationnement
# 96  DY3638          Norwegian        active         Nécessite un stationnement
# 97  AF1067         Air France        active         Nécessite un stationnement
# 98  WS5173            WestJet        active         Nécessite un stationnement
# 99  KL2127                KLM        active         Nécessite un stationnement
#
# [100 rows x 4 columns]

# %%
import pickle
# Charger le modèle
model_path = "/Users/benothmane/Desktop/flight_dashboard/models/new_models.pkl"
try:
    with open(model_path, "rb") as model_file:
        model = pickle.load(model_file)
        if not hasattr(model, "predict"):
            raise ValueError("Le modèle chargé n'est pas valide.")
except Exception as e:
    print(f"Erreur lors du chargement du modèle : {e}")
# Out:
# Erreur lors du chargement du modèle : Le modèle chargé n'est pas valide.

# %%
import os

model_path = "/Users/benothmane/Desktop/flight_dashboard/models/new_models.pkl"
if not os.path.exists(model_path):
    print("Le fichier du modèle n'existe pas.")
else:
    print("Le fichier du modèle existe.")
# Out:
# Le fichier du modèle existe.

# %%
# Vérifiez le contenu du fichier du modèle
with open(model_path, "rb") as model_file:
    content = model_file.read(20)  # Lire les 20 premiers octets
    print(content)
# Out:
# b'\x80\x04\x95g\x03\x00\x00\x00\x00\x00\x00\x8c\x18sklearn'

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.2

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import pickle

# Créer un jeu de données d'exemple
data = {
    'feature1': [1, 2, 3, 4, 5],
    'feature2': [5, 4, 3, 2, 1],
    'target': [0, 1, 0, 1, 0]
}
df = pd.DataFrame(data)

# Séparer les caractéristiques et la cible
X = df[['feature1', 'feature2']]
y = df['target']

# Entraîner le modèle
model = RandomForestClassifier()
model.fit(X, y)

# Sauvegarder le modèle
model_path = "/Users/benothmane/Desktop/flight_dashboard/models/new_models.pkl"
with open(model_path, "wb") as model_file:
    pickle.dump(model, model_file)

print("Modèle réentraîné et sauvegardé avec succès.")
# Out:
# Modèle réentraîné et sauvegardé avec succès.
